# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")

# %%
df= pd.read_csv('diff_saturated.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated original-flat anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated original-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated original-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated original-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated original-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated original-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('diff_saturated.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat study conditions.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions study conditions.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions study conditions.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions study conditions.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions study conditions.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions study conditions.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions study conditions.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions study conditions.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions study conditions.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated original-flat study conditions")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated original-one feasible value reactions study conditions")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated original-Ushaped_reactions study conditions")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated original-monotonically decreasing and stable reactions study conditions")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated original-monotonically decreasing only reactions study conditions")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated original-monotonically increasing only reactions study conditions")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated original-monotonically increasing and stable reactions study conditions")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated original-increasing and decreasing and stable reactions study conditions")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated original-increasing and decreasing only reactions study conditions")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 2

# %%
df= pd.read_csv('diff_saturated.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated original-flat lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated original-one feasible value reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated original-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated original-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated original-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated original-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('diff_saturated.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated original-flat M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated original-one feasible value reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated original-Ushaped_reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated original-monotonically decreasing and stable reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated original-monotonically decreasing only reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated original-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated original-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated original-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated original-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 3

# %%
df= pd.read_csv('flat.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat original-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat original-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat original-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat original-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat original-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('one feasible value reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value original-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value original-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value original-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value original-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('Ushaped_reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped original-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped original-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped original-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 3

# %%
df= pd.read_csv('monotonically decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable original-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable original-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable original-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 6

# %%
df= pd.read_csv('monotonically decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only original-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only original-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only original-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 8

# %%
df= pd.read_csv('monotonically increasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only original-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only original-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only original-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only original-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 10

# %%
df= pd.read_csv('monotonically increasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable original-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable original-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable original-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable original-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable original-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 2

# %%
df= pd.read_csv('increasing and decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable original-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable original-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable original-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable original-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable original-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable original-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 25

# %%
df= pd.read_csv('increasing and decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only original-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only original-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only original-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only original-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only original-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only original-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only original-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only original-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only original-increasing and decreasing and stable reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 11

# %%
df= pd.read_csv('flat.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat original-one feasible value reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat original-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat original-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat original-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat original-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 3

# %%
df= pd.read_csv('one feasible value reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value original-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value original-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value original-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value original-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 4

# %%
df= pd.read_csv('Ushaped_reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped original-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped original-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped original-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('monotonically decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable original-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable original-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable original-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('monotonically decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only original-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only original-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only original-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 13

# %%
df= pd.read_csv('monotonically increasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only original-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only original-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only original-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only original-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 19

# %%
df= pd.read_csv('monotonically increasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable original-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable original-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable original-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable original-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable original-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('increasing and decreasing and stable reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable original-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable original-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable original-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable original-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable original-monotonically increasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable original-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 9

# %%
df= pd.read_csv('increasing and decreasing only reactions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only original-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only original-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only original-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only original-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only original-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only original-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only original-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only original-monotonically increasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only original-increasing and decreasing and stable reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 20

# %%
len(D)
# Out:
# 0
